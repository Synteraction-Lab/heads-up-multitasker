# %%
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Given series of data
# data_series = [
#     np.array([0.00218507, 0.03347532, 0.09417323, 0.05501498, 0.00875916,
#               0.08620109, 0.23996987, 0.15742538, 0.01670788, 0.08684666,
#               0.149734, 0.06950736]),
#     np.array([0.00037151, 0.013031, 0.05653922, 0.02837456, 0.00697193,
#               0.07513369, 0.24862493, 0.14487353, 0.02155648, 0.11251412,
#               0.20269513, 0.0893139]),
#     np.array([0.0011267, 0.0123349, 0.02880708, 0.00618273, 0.03306244,
#               0.13655101, 0.19631787, 0.04328504, 0.10439648, 0.23117878,
#               0.17708987, 0.0296671]),
#     np.array([0.00071603, 0.00576581, 0.00852344, 0.00190694, 0.03308024,
#               0.13167843, 0.12161572, 0.02172222, 0.14640375, 0.32592534,
#               0.17754757, 0.02511452])
# ]

# # Adjusted grid shape to accommodate extra rows
# grid_shape = (5, 4)

# # Number of NaN rows to determine the gap size
# gap_size = 1

# # Plotting the series of heatmaps
# for i, data in enumerate(data_series):
#     plt.figure(figsize=(10, 6))
    
#     # Reshape data to 3x4
#     data_reshaped = data.reshape(3, 4)
    
#     # Inserting rows of NaNs between the middle and last rows
#     for _ in range(gap_size):
#         data_reshaped = np.insert(data_reshaped, [1, 2], np.nan, axis=0)
    
#     sns.heatmap(data_reshaped, annot=True, cmap="YlGnBu", cbar=True, xticklabels=False, yticklabels=False)
#     plt.title(f'Probability Distribution Heatmap {i + 1}')
#     plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# [26, 30, 29, 28, 32, 31, 30, 34, 35] --> real target: 35

# Given series of data
data_series = [
    np.array([0.05619344, 0.20885827, 0.05619344, 0.00109443, 0.03135295,
       0.11653182, 0.03135295, 0.00061063, 0.00544575, 0.03044023,
       0.46129819, 0.0006279 ]), 
    np.array([1.92007808e-02, 1.37584017e-01, 1.92007808e-02, 5.21881134e-05,
       1.43421850e-02, 1.02769541e-01, 1.43421850e-02, 3.89823510e-05,
       1.86076842e-03, 3.05934357e-02, 6.59222140e-01, 7.92995182e-04]), 
    np.array([5.26883590e-02, 1.95830682e-01, 3.81401628e-03, 3.89242352e-07,
       5.26883590e-02, 1.95830682e-01, 3.81401628e-03, 3.89242352e-07,
       5.10616201e-03, 6.80188213e-02, 4.22073966e-01, 1.34157230e-04]), 
    np.array([4.20438969e-04, 4.16182859e-02, 5.80811346e-03, 1.14276168e-06,
       3.14050430e-04, 3.10871293e-02, 4.33841929e-03, 8.53595468e-07,
       1.26844515e-05, 5.71549587e-03, 8.93770248e-01, 1.69131382e-02]), 
    np.array([8.98598052e-07, 2.36898255e-03, 2.36898255e-03, 8.98598052e-07,
       8.98598052e-07, 2.36898255e-03, 2.36898255e-03, 8.98598052e-07,
       2.72100480e-08, 1.43711792e-03, 9.60425261e-01, 2.86580691e-02]), 
    np.array([2.63934204e-08, 4.98587243e-04, 9.61223090e-04, 1.89123185e-07,
       3.53345240e-08, 6.67489951e-04, 1.28684952e-03, 2.53191046e-07,
       2.52820722e-09, 4.65366343e-03, 9.81548967e-01, 1.03827132e-02]), 
    np.array([1.05624036e-08, 3.84672623e-04, 3.84672623e-04, 1.05624036e-08,
       1.89308407e-08, 6.89443083e-04, 6.89443083e-04, 1.89308407e-08,
       3.02593048e-08, 2.04081362e-02, 9.75646271e-01, 1.79727216e-03]), 
    np.array([1.30551393e-09, 9.16627874e-05, 4.75455666e-05, 1.82193304e-10,
       5.61434839e-09, 3.94194817e-04, 2.04469190e-04, 7.83520319e-10,
       4.75362785e-08, 3.31520937e-02, 9.64741376e-01, 1.36860294e-03]), 
    np.array([1.19596664e-11, 6.01699590e-06, 6.01699590e-06, 1.19596664e-11,
       1.23409225e-10, 6.20880865e-05, 6.20880865e-05, 1.23409247e-10,
       4.58136371e-09, 1.20486361e-02, 9.82468484e-01, 5.34666536e-03])
]

# Reshape data to form a 2D grid (in this case 3x4 as an example)
grid_shape = (3, 4)

# Plotting the series of heatmaps
for i, data in enumerate(data_series):
    plt.figure(figsize=(10, 6))
    data_reshaped = data.reshape(grid_shape)
    sns.heatmap(data_reshaped, annot=True, cmap="YlGnBu", cbar=True, xticklabels=False, yticklabels=False)
#     plt.title(f'Belief (Probability) Distribution Heatmap Step {i + 1} Across all 16 words in the layout')
    plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# [26, 30, 29, 33] --> real target: 33

# Given series of data
data_series = [
    np.array([5.61349571e-02, 2.08640906e-01, 5.61349571e-02, 1.09328956e-03,
       3.13203246e-02, 1.16410544e-01, 3.13203371e-02, 1.91831911e-03,
       4.61066956e-01, 3.04133794e-02, 5.44007867e-03, 1.05951386e-04]), 
    np.array([1.91827462e-02, 1.37454790e-01, 1.91827462e-02, 5.21390950e-05,
       1.43287139e-02, 1.02673013e-01, 1.43287291e-02, 1.14412807e-03,
       6.59210069e-01, 3.05788523e-02, 1.85902068e-03, 5.05283281e-06]), 
    np.array([8.22044388e-03, 3.05535258e-02, 5.95063263e-04, 6.07296370e-08,
       8.22044388e-03, 3.05535258e-02, 5.95065047e-04, 2.85958230e-05,
       9.10556561e-01, 1.06190398e-02, 5.76690856e-05, 5.88534770e-09]), 
    np.array([1.05991282e-03, 2.04339900e-03, 5.55400011e-06, 2.12827757e-11,
       2.54320198e-03, 4.90302249e-03, 1.33273693e-05, 1.54723664e-05,
       9.83186197e-01, 6.22818330e-03, 1.73011039e-06, 6.62542876e-12])
]

# # [34] --> 25
# data_series = [
#     np.array([4.64462942e-01, 3.04033672e-02, 5.41779505e-03, 1.05517387e-04,
#        3.11920302e-02, 1.15933703e-01, 3.11920302e-02, 6.07498834e-04,
#        5.59050169e-02, 2.07786271e-01, 5.59050169e-02, 1.08881122e-03])
# ]

# Reshape data to form a 2D grid (in this case 3x4 as an example)
grid_shape = (3, 4)

# Plotting the series of heatmaps
for i, data in enumerate(data_series):
    plt.figure(figsize=(10, 6))
    data_reshaped = data.reshape(grid_shape)
    ax = sns.heatmap(data_reshaped, annot=True, cmap="YlGnBu", cbar=True, 
                     vmin=0, vmax=1, 
                     xticklabels=False, yticklabels=False, 
                     annot_kws={"size": 12, 'color':'black', 'weight':'bold'})

    # Custom logic to position the annotations
    for text in ax.texts:
        text.set_position((text.get_position()[0] + 0.1, text.get_position()[1] - 0.4))
        text.set_horizontalalignment('left')
        text.set_verticalalignment('top')
    
    plt.title(f'Step {i + 1}')

    plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# [26, 25, 29] --> real target: 29

# Given series of data
data_series = [
    np.array([2.26351276e-02, 8.41296365e-02, 2.26351377e-02, 1.53142754e-03,
       7.78664572e-01, 6.49459775e-02, 1.26292061e-02, 2.45967435e-04,
       2.19358460e-03, 8.15305651e-03, 2.19358460e-03, 4.27224542e-05]), 
    np.array([1.27148144e-02, 2.45128076e-02, 9.20403975e-04, 2.67697049e-05,
       9.42672872e-01, 1.76175625e-02, 3.83590762e-04, 2.80513539e-07,
       3.83589918e-04, 7.39520499e-04, 2.77673897e-05, 2.03058745e-08]), 
    np.array([3.88280785e-03, 3.88280785e-03, 2.03467632e-05, 1.42938236e-05,
       9.84571337e-01, 7.38216127e-03, 1.13529019e-05, 3.11706587e-10,
       1.17139417e-04, 1.17139417e-04, 6.13816841e-07, 1.68542830e-11])
]

# # [34] --> 25
# data_series = [
#     np.array([4.64462942e-01, 3.04033672e-02, 5.41779505e-03, 1.05517387e-04,
#        3.11920302e-02, 1.15933703e-01, 3.11920302e-02, 6.07498834e-04,
#        5.59050169e-02, 2.07786271e-01, 5.59050169e-02, 1.08881122e-03])
# ]

# Reshape data to form a 2D grid (in this case 3x4 as an example)
grid_shape = (3, 4)

# Plotting the series of heatmaps
for i, data in enumerate(data_series):
    plt.figure(figsize=(10, 6))
    data_reshaped = data.reshape(grid_shape)
    ax = sns.heatmap(data_reshaped, annot=True, cmap="YlGnBu", cbar=True, 
                     vmin=0, vmax=1, 
                     xticklabels=False, yticklabels=False, 
                     annot_kws={"size": 12, 'color':'gray', 'weight':'bold'},
                     linewidths=0.1, linecolor='black')

    # Custom logic to position the annotations
    for text in ax.texts:
        text.set_position((text.get_position()[0], text.get_position()[1] - 0.4))
        text.set_horizontalalignment('left')
        text.set_verticalalignment('top')
    
#     plt.title(f'Step {i + 1}')

    plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

       1.82889878e-10, 6.65138066e-04, 3.23528734e-02, 9.33849763e-02])
]

# Reshape data to form a 2D grid (in this case 3x4 as an example)
grid_shape = (3, 4)

# Plotting the series of heatmaps
for i, data in enumerate(data_series):
    plt.figure(figsize=(10, 6))
    data_reshaped = data.reshape(grid_shape)
    ax = sns.heatmap(data_reshaped, annot=True, cmap="YlGnBu", cbar=True, 
                     vmin=0, vmax=1, 
                     xticklabels=False, yticklabels=False, 
                     annot_kws={"size": 12, 'color':'gray', 'weight':'bold'},
                     linewidths=0.1, linecolor='black')

    # Custom logic to position the annotations
    for text in ax.texts:
        text.set_position((text.get_position()[0], text.get_position()[1] - 0.4))
        text.set_horizontalalignment('left')
        text.set_verticalalignment('top')
    
#     plt.title(f'Step {i + 1}')

    plt.show()

# %%
# Gaze positions [18, 17, 21, target is 21


# Given series of data
data_series = [
    np.array([0.00685579, 0.01992192, 0.01408397, 0.00388291, 0.1314241 ,
       0.35295657, 0.20929629, 0.03783066, 0.06032846, 0.10488857,
       0.05043533, 0.00809544]), 
    np.array([0.00760128, 0.01146967, 0.00378582, 0.00050793, 0.28536969,
       0.38426736, 0.07682879, 0.00493417, 0.12132869, 0.08657614,
       0.01624865, 0.00108183]), 
    np.array([3.70569719e-04, 4.23424182e-04, 1.41793324e-04, 2.22696071e-05,
       1.67664828e-01, 1.44160728e-01, 1.77891229e-02, 1.49602037e-03,
       4.04760752e-01, 2.22543337e-01, 3.77953716e-02, 2.83178247e-03])]


# Reshape data to form a 2D grid (in this case 3x4 as an example)
grid_shape = (3, 4)

# Plotting the series of heatmaps
for i, data in enumerate(data_series):
    plt.figure(figsize=(10, 6))
    data_reshaped = data.reshape(grid_shape)
    sns.heatmap(data_reshaped, annot=True, cmap="YlGnBu", cbar=True)
    plt.title(f'Probability Distribution Heatmap {i + 1}')
    plt.show()

# %%
# Gaze positions [10, 11], target is 11


# Given series of data
data_series = [
    np.array([2.77655785e-08, 1.09713079e-07, 1.58137456e-07, 8.31711813e-08,
       1.84634236e-03, 5.06178754e-03, 4.61738365e-03, 1.54649309e-03,
       2.11062208e-01, 4.86789872e-01, 2.50527758e-01, 3.85477761e-02]), 
    np.array([8.30109014e-09, 8.00993141e-08, 2.82524086e-07, 3.64267252e-07,
       4.69516654e-04, 3.17261241e-03, 7.48530078e-03, 6.43327846e-03,
       5.51359972e-02, 3.70418844e-01, 4.09079144e-01, 1.47804572e-01])]



# Reshape data to form a 2D grid (in this case 3x4 as an example)
grid_shape = (3, 4)

# Plotting the series of heatmaps
for i, data in enumerate(data_series):
    plt.figure(figsize=(10, 6))
    data_reshaped = data.reshape(grid_shape)
    sns.heatmap(data_reshaped, annot=True, cmap="YlGnBu", cbar=True)
    plt.title(f'Probability Distribution Heatmap {i + 1}')
    plt.show()
